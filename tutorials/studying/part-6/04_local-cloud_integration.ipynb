# %% [markdown]
# ---
# technologies: "Local-Cloud Integration"
# category: "Choice and use of technology"
# difficulty: "Expert"
# ---
#
# # Local-Cloud Integration
#
# ## Used material
#
# 1. <span id="used-material-1"></span>
#
# ## Why use Local-Cloud Integration?
#
# ## How to use Local-Cloud Integration?
